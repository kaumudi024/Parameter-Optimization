# %%
# Library Inclusion
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# Variables declaration
bestAccuracy = 0
bestKernel = None
bestC = 0
bestGamma = 0
iteration = 100
kernelList = ['rbf', 'sigmoid', 'poly', 'linear', 'precomputed']

# %%
# Loading dataset (Wine Quality)
data = load_wine()
X = data.data
y = data.target

# Data Scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Dividing the dataset into 70/30 for training and testing
X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# fitnessFunction declaration
def fitnessFunction(k, c, g):
    # Train the model
    model = SVC(C=c, gamma=g)
    model.fit(X_train_all, y_train_all)
    
    # Prediction
    predicted = model.predict(X_test_all)
    
    # Model Evaluation: Accuracy
    accuracy = np.mean(y_test_all == predicted) * 100
    
    return accuracy

# %%
# Program Execution
for i in range(iteration):
    k = np.random.choice(kernelList, 1)[0]
    c = np.random.uniform(0.01, 10.0)  # Generating C within the feasible range
    g = np.random.random()
    accuracy = fitnessFunction(k, c, g)

    if accuracy > bestAccuracy:
        bestKernel = k
        bestC = c
        bestGamma = g
        bestAccuracy = accuracy

    print(f"Iteration {i + 1}: Best Accuracy: {bestAccuracy}, Best Kernel: {bestKernel}, Best C: {bestC}, Best Gamma: {bestGamma}")
# Out:
# Iteration 1: Best Accuracy: 72.22222222222221, Best Kernel: poly, Best C: 3.2774134545099454, Best Gamma: 0.783770235684665
# Iteration 2: Best Accuracy: 74.07407407407408, Best Kernel: sigmoid, Best C: 1.6602792531624098, Best Gamma: 0.6842642573995664
# Iteration 3: Best Accuracy: 74.07407407407408, Best Kernel: sigmoid, Best C: 1.6602792531624098, Best Gamma: 0.6842642573995664
# Iteration 4: Best Accuracy: 87.03703703703704, Best Kernel: precomputed, Best C: 6.568231817859903, Best Gamma: 0.5385126848282122
# Iteration 5: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 6: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 7: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 8: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 9: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 10: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 11: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 12: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 13: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 14: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 15: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 16: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 17: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 18: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 19: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 20: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 21: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 22: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 23: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 24: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 25: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 26: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 27: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 28: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 29: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 30: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 31: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 32: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 33: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 34: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 35: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 36: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 37: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 38: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 39: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 40: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 41: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 42: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 43: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 44: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 45: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 46: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 47: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 48: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 49: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 50: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 51: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 52: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 53: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 54: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 55: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 56: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 57: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 58: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 59: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 60: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 61: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 62: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 63: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 64: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 65: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 66: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 67: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 68: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 69: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 70: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 71: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 72: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 73: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 74: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 75: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 76: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 77: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 78: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 79: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 80: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 81: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 82: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 83: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 84: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 85: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 86: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 87: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 88: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 89: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 90: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 91: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 92: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 93: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 94: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 95: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 96: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 97: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 98: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 99: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921
# Iteration 100: Best Accuracy: 100.0, Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921

# %%
print(f"Best Kernel: {bestKernel}, Best C: {bestC}, Best Gamma: {bestGamma}, Best Accuracy: {bestAccuracy}")
# Out:
# Best Kernel: rbf, Best C: 7.132307370476703, Best Gamma: 0.05326825262877921, Best Accuracy: 100.0

# %%
# Plot the convergence graph accuracy vs iterations
convergence = np.zeros(iteration)
for i in range(iteration):
    k = np.random.choice(kernelList, 1)[0]
    c = np.random.uniform(0.01, 10.0)  # Generating C within the feasible range
    g = np.random.random()
    accuracy = fitnessFunction(k, c, g)
    convergence[i] = accuracy

plt.figure(figsize=(10, 6))
plt.plot(np.arange(iteration), convergence,color='red')
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Convergence of SVC")
plt.grid(True)
plt.show()
plt.savefig('graph.png')
